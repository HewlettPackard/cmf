# %% [markdown]
# ### This Jupyter notebook provides examples of how the pipeline metadata stored with CMF tracking layer can be queried with CMF query layer.

# %%
import ml_metadata as mlmd
from ml_metadata.metadata_store import metadata_store
from ml_metadata.proto import metadata_store_pb2

# %%
connection_config = metadata_store_pb2.ConnectionConfig()
connection_config.sqlite.filename_uri = 'mlmd'
connection_config.sqlite.connection_mode = 3 # READWRITE_OPENCREATE
store = metadata_store.MetadataStore(connection_config)

# %%
ids = store.get_executions()
print(ids)
# Out:
# [id: 1
# type_id: 12
# properties {
#   key: "Context_ID"
#   value {
#     int_value: 2
#   }
# }
# properties {
#   key: "Context_Type"
#   value {
#     string_value: "active_learning/Initial_select"
#   }
# }
# properties {
#   key: "Execution"
#   value {
#     string_value: "[\'initial_select.py\', \'configs/MIAOD-GRAY.py\', \'--work_directory\', \'work_dirs/test\', \'--labeled_next\', \'work_dirs/test/X_L_0.npy\', \'--unselected\', \'work_dirs/test/X_U_0.npy\']"
#   }
# }
# properties {
#   key: "Git_End_Commit"
#   value {
#     string_value: ""
#   }
# }
# properties {
#   key: "Git_Repo"
#   value {
#     string_value: "/tmp/remote"
#   }
# }
# properties {
#   key: "Git_Start_Commit"
#   value {
#     string_value: "62bc1f873091a1ddee42228601857e722f05b92a"
#   }
# }
# properties {
#   key: "Pipeline_Type"
#   value {
#     string_value: "active_learning"
#   }
# }
# properties {
#   key: "Pipeline_id"
#   value {
#     int_value: 1
#   }
# }
# custom_properties {
#   key: "config"
#   value {
#     string_value: "Config (path: configs/MIAOD-GRAY.py): {\'model\': {\'type\': \'RetinaNet\', \'pretrained\': \'torchvision://resnet50\', \'backbone\': {\'type\': \'ResNet\', \'depth\': 50, \'num_stages\': 4, \'out_indices\': (0, 1, 2, 3), \'frozen_stages\': 1, \'norm_cfg\': {\'type\': \'BN\', \'requires_grad\': True}, \'norm_eval\': True, \'style\': \'pytorch\'}, \'neck\': {\'type\': \'FPN\', \'in_channels\': [256, 512, 1024, 2048], \'out_channels\': 256, \'start_level\': 1, \'add_extra_convs\': \'on_input\', \'num_outs\': 5}, \'bbox_head\': {\'type\': \'MIAODRetinaHead\', \'C\': 1, \'in_channels\': 256, \'stacked_convs\': 4, \'feat_channels\': 256, \'anchor_generator\': {\'type\': \'AnchorGenerator\', \'octave_base_scale\': 4, \'scales_per_octave\': 3, \'ratios\': [0.5, 1.0, 2.0], \'strides\': [8, 16, 32, 64, 128]}, \'bbox_coder\': {\'type\': \'DeltaXYWHBBoxCoder\', \'target_means\': [0.0, 0.0, 0.0, 0.0], \'target_stds\': [1.0, 1.0, 1.0, 1.0]}, \'FL\': {\'type\': \'FocalLoss\', \'use_sigmoid\': True, \'gamma\': 2.0, \'alpha\': 0.25, \'loss_weight\': 1.0}, \'SmoothL1\': {\'type\': \'L1Loss\', \'loss_weight\': 1.0}}}, \'train_cfg\': {\'assigner\': {\'type\': \'MaxIoUAssigner\', \'pos_iou_thr\': 0.5, \'neg_iou_thr\': 0.4, \'min_pos_iou\': 0, \'ignore_iof_thr\': -1}, \'allowed_border\': -1, \'pos_weight\': -1, \'debug\': False, \'param_lambda\': 0.5}, \'test_cfg\': {\'nms_pre\': 1000, \'min_bbox_size\': 0, \'score_thr\': 0.05, \'nms\': {\'type\': \'nms\', \'iou_threshold\': 0.5}, \'max_per_img\': 100}, \'theta_f_1\': [\'bbox_head.f_1_convs.0.conv.weight\', \'bbox_head.f_1_convs.0.conv.bias\', \'bbox_head.f_1_convs.1.conv.weight\', \'bbox_head.f_1_convs.1.conv.bias\', \'bbox_head.f_1_convs.2.conv.weight\', \'bbox_head.f_1_convs.2.conv.bias\', \'bbox_head.f_1_convs.3.conv.weight\', \'bbox_head.f_1_convs.3.conv.bias\', \'bbox_head.f_1_retina.weight\', \'bbox_head.f_1_retina.bias\'], \'theta_f_2\': [\'bbox_head.f_2_convs.0.conv.weight\', \'bbox_head.f_2_convs.0.conv.bias\', \'bbox_head.f_2_convs.1.conv.weight\', \'bbox_head.f_2_convs.1.conv.bias\', \'bbox_head.f_2_convs.2.conv.weight\', \'bbox_head.f_2_convs.2.conv.bias\', \'bbox_head.f_2_convs.3.conv.weight\', \'bbox_head.f_2_convs.3.conv.bias\', \'bbox_head.f_2_retina.weight\', \'bbox_head.f_2_retina.bias\'], \'data_root\': \'hdcdatasets/\', \'dataset_type\': \'HDCDataset\', \'img_norm_cfg\': {\'mean\': [123.675, 123.675, 123.675], \'std\': [58.395, 58.395, 58.395], \'to_rgb\': True}, \'train_pipeline\': [{\'type\': \'LoadImageFromFile\'}, {\'type\': \'LoadAnnotations\', \'with_bbox\': True}, {\'type\': \'Resize\', \'img_scale\': (960, 960), \'keep_ratio\': True}, {\'type\': \'RandomFlip\', \'flip_ratio\': 0.5}, {\'type\': \'RandomFlip\', \'flip_ratio\': 0.5, \'direction\': \'vertical\'}, {\'type\': \'Normalize\', \'mean\': [123.675, 123.675, 123.675], \'std\': [58.395, 58.395, 58.395], \'to_rgb\': True}, {\'type\': \'Pad\', \'size_divisor\': 32}, {\'type\': \'DefaultFormatBundle\'}, {\'type\': \'Collect\', \'keys\': [\'img\', \'gt_bboxes\', \'gt_labels\']}], \'test_pipeline\': [{\'type\': \'LoadImageFromFile\'}, {\'type\': \'MultiScaleFlipAug\', \'img_scale\': (960, 960), \'flip\': False, \'transforms\': [{\'type\': \'Resize\', \'keep_ratio\': True}, {\'type\': \'RandomFlip\', \'flip_ratio\': 0.5}, {\'type\': \'RandomFlip\', \'flip_ratio\': 0.5, \'direction\': \'vertical\'}, {\'type\': \'Normalize\', \'mean\': [123.675, 123.675, 123.675], \'std\': [58.395, 58.395, 58.395], \'to_rgb\': True}, {\'type\': \'Pad\', \'size_divisor\': 32}, {\'type\': \'ImageToTensor\', \'keys\': [\'img\']}, {\'type\': \'Collect\', \'keys\': [\'img\']}]}], \'data\': {\'samples_per_gpu\': 8, \'workers_per_gpu\': 8, \'train\': {\'type\': \'RepeatDataset\', \'times\': 3, \'dataset\': {\'type\': \'HDCDataset\', \'ann_file\': [\'hdcdatasets/hdc_single/ImageSets/Main/trainval.txt\'], \'img_prefix\': [\'hdcdatasets/hdc_single/\'], \'pipeline\': [{\'type\': \'LoadImageFromFile\'}, {\'type\': \'LoadAnnotations\ ...
#   }
# }
# custom_properties {
#   key: "env"
#   value {
#     string_value: "{\'sys.platform\': \'linux\', \'Python\': \'3.8.15 (default, Nov 24 2022, 15:19:38) [GCC 11.2.0]\', \'CUDA available\': True, \'CUDA_HOME\': \'/usr/local/cuda\', \'NVCC\': \'Build cuda_11.1.TC455_06.29190527_0\', \'GPU 0,1,2,3,4,5,6,7\': \'Tesla V100-SXM2-16GB\', \'GCC\': \'gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0\', \'PyTorch\': \'1.10.0+cu111\', \'PyTorch compiling details\': \'PyTorch built with:\\n  - GCC 7.3\\n  - C++ Version: 201402\\n  - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications\\n  - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)\\n  - OpenMP 201511 (a.k.a. OpenMP 4.5)\\n  - LAPACK is enabled (usually provided by MKL)\\n  - NNPACK is enabled\\n  - CPU capability usage: AVX512\\n  - CUDA Runtime 11.1\\n  - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86\\n  - CuDNN 8.0.5\\n  - Magma 2.5.2\\n  - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.1, CUDNN_VERSION=8.0.5, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, \\n\', \'TorchVision\': \'0.11.0+cu111\', \'OpenCV\': \'4.6.0\', \'MMCV\': \'1.5.0\', \'MMDetection\': \'2.3.0+62bc1f8\', \'MMDetection Compiler\': \'GCC 7.5\', \'MMDetection CUDA Compiler\': \'11.1\'}"
#   }
# }
# create_time_since_epoch: 1680746889923
# last_update_time_since_epoch: 1680746889923
# , id: 2
# type_id: 15
# properties {
#   key: "Context_ID"
#   value {
#     int_value: 3
#   }
# }
# properties {
#   key: "Context_Type"
#   value {
#     string_value: "active_learning/Train"
#   }
# }
# properties {
#   key: "Execution"
#   value {
#     string_value: "[\'cycle_train.py\', \'configs/MIAOD-GRAY.py\', \'--work_directory\', \'work_dirs/test\', \'--cycle\', \'0\', \'--labeled\', \'work_dirs/test/X_L_0.npy\', \'--unselected\', \'work_dirs/test/X_U_0.npy\', \'--model\', \'work_dirs/test/cycle_0.pth\']"
#   }
# }
# properties {
#   key: "Git_End_Commit"
#   value {
#     string_value: ""
#   }
# }
# properties {
#   key: "Git_Repo"
#   value {
#     string_value: "/tmp/remote"
#   }
# }
# properties {
#   key: "Git_Start_Commit"
#   value {
#     string_value: "62bc1f873091a1ddee42228601857e722f05b92a"
#   }
# }
# properties {
#   key: "Pipeline_Type"
#   value {
#     string_value: "active_learning"
#   }
# }
# properties {
#   key: "Pipeline_id"
#   value {
#     int_value: 1
#   }
# }
# custom_properties {
#   key: "env"
#   value {
#     string_value: "{\'sys.platform\': \'linux\', \'Python\': \'3.8.15 (default, Nov 24 2022, 15:19:38) [GCC 11.2.0]\', \'CUDA available\': True, \'CUDA_HOME\': \'/usr/local/cuda\', \'NVCC\': \'Build cuda_11.1.TC455_06.29190527_0\', \'GPU 0,1,2,3,4,5,6,7\': \'Tesla V100-SXM2-16GB\', \'GCC\': \'gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0\', \'PyTorch\': \'1.10.0+cu111\', \'PyTorch compiling details\': \'PyTorch built with:\\n  - GCC 7.3\\n  - C++ Version: 201402\\n  - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications\\n  - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)\\n  - OpenMP 201511 (a.k.a. OpenMP 4.5)\\n  - LAPACK is enabled (usually provided by MKL)\\n  - NNPACK is enabled\\n  - CPU capability usage: AVX512\\n  - CUDA Runtime 11.1\\n  - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86\\n  - CuDNN 8.0.5\\n  - Magma 2.5.2\\n  - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.1, CUDNN_VERSION=8.0.5, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, \\n\', \'TorchVision\': \'0.11.0+cu111\', \'OpenCV\': \'4.6.0\', \'MMCV\': \'1.5.0\', \'MMDetection\': \'2.3.0+62bc1f8\', \'MMDetection Compiler\': \'GCC 7.5\', \'MMDetection CUDA Compiler\': \'11.1\'}"
#   }
# }
# custom_properties {
#   key: "seed"
#   value {
#     string_value: "666"
#   }
# }
# name: "Train-0"
# create_time_since_epoch: 1680746943815
# last_update_time_since_epoch: 1680746943815
# , id: 3
# type_id: 19
# properties {
#   key: "Context_ID"
#   value {
#     int_value: 4
#   }
# }
# properties {
#   key: "Context_Type"
#   value {
#     string_value: "active_learning/Cycle_Select"
#   }
# }
# properties {
#   key: "Execution"
#   value {
#     string_value: "[\'cycle_select.py\', \'configs/MIAOD-GRAY.py\', \'--work_directory\', \'work_dirs/test\', \'--cycle\', \'0\', \'--model\', \'work_dirs/test/cycle_0.pth\', \'--labeled\', \'work_dirs/test/X_L_0.npy\', \'--labeled_next\', \'work_dirs/test/X_L_1.npy\', \'--unselected\', \'work_dirs/test/X_U_1.npy\']"
#   }
# }
# properties {
#   key: "Git_End_Commit"
#   value {
#     string_value: ""
#   }
# }
# properties {
#   key: "Git_Repo"
#   value {
#     string_value: "/tmp/remote"
#   }
# }
# properties {
#   key: "Git_Start_Commit"
#   value {
#     string_value: "5462a60d81b5b72eeb60c99b8decde79a63b4c04"
#   }
# }
# properties {
#   key: "Pipeline_Type"
#   value {
#     string_value: "active_learning"
#   }
# }
# properties {
#   key: "Pipeline_id"
#   value {
#     int_value: 1
#   }
# }
# custom_properties {
#   key: "config"
#   value {
#     string_value: "<class \'mmcv.utils.config.Config\'>"
#   }
# }
# custom_properties {
#   key: "env"
#   value {
#     string_value: "{\'sys.platform\': \'linux\', \'Python\': \'3.8.15 (default, Nov 24 2022, 15:19:38) [GCC 11.2.0]\', \'CUDA available\': True, \'CUDA_HOME\': \'/usr/local/cuda\', \'NVCC\': \'Build cuda_11.1.TC455_06.29190527_0\', \'GPU 0,1,2,3,4,5,6,7\': \'Tesla V100-SXM2-16GB\', \'GCC\': \'gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0\', \'PyTorch\': \'1.10.0+cu111\', \'PyTorch compiling details\': \'PyTorch built with:\\n  - GCC 7.3\\n  - C++ Version: 201402\\n  - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications\\n  - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)\\n  - OpenMP 201511 (a.k.a. OpenMP 4.5)\\n  - LAPACK is enabled (usually provided by MKL)\\n  - NNPACK is enabled\\n  - CPU capability usage: AVX512\\n  - CUDA Runtime 11.1\\n  - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86\\n  - CuDNN 8.0.5\\n  - Magma 2.5.2\\n  - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.1, CUDNN_VERSION=8.0.5, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, \\n\', \'TorchVision\': \'0.11.0+cu111\', \'OpenCV\': \'4.6.0\', \'MMCV\': \'1.5.0\', \'MMDetection\': \'2.3.0+5462a60\', \'MMDetection Compiler\': \'GCC 7.5\', \'MMDetection CUDA Compiler\': \'11.1\'}"
#   }
# }
# create_time_since_epoch: 1680747437631
# last_update_time_since_epoch: 1680747437631
# , id: 4
# type_id: 15
# properties {
#   key: "Context_ID"
#   value {
#     int_value: 3
#   }
# }
# properties {
#   key: "Context_Type"
#   value {
#     string_value: "active_learning/Train"
#   }
# }
# properties {
#   key: "Execution"
#   value {
#     string_value: "[\'cycle_train.py\', \'configs/MIAOD-GRAY.py\', \'--work_directory\', \'work_dirs/test\', \'--cycle\', \'1\', \'--labeled\', \'work_dirs/test/X_L_1.npy\', \'--unselected\', \'work_dirs/test/X_U_1.npy\', \'--model\', \'work_dirs/test/cycle_1.pth\']"
#   }
# }
# properties {
#   key: "Git_End_Commit"
#   value {
#     string_value: ""
#   }
# }
# properties {
#   key: "Git_Repo"
#   value {
#     string_value: "/tmp/remote"
#   }
# }
# properties {
#   key: "Git_Start_Commit"
#   value {
#     string_value: "5462a60d81b5b72eeb60c99b8decde79a63b4c04"
#   }
# }
# properties {
#   key: "Pipeline_Type"
#   value {
#     string_value: "active_learning"
#   }
# }
# properties {
#   key: "Pipeline_id"
#   value {
#     int_value: 1
#   }
# }
# custom_properties {
#   key: "env"
#   value {
#     string_value: "{\'sys.platform\': \'linux\', \'Python\': \'3.8.15 (default, Nov 24 2022, 15:19:38) [GCC 11.2.0]\', \'CUDA available\': True, \'CUDA_HOME\': \'/usr/local/cuda\', \'NVCC\': \'Build cuda_11.1.TC455_06.29190527_0\', \'GPU 0,1,2,3,4,5,6,7\': \'Tesla V100-SXM2-16GB\', \'GCC\': \'gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0\', \'PyTorch\': \'1.10.0+cu111\', \'PyTorch compiling details\': \'PyTorch built with:\\n  - GCC 7.3\\n  - C++ Version: 201402\\n  - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications\\n  - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)\\n  - OpenMP 201511 (a.k.a. OpenMP 4.5)\\n  - LAPACK is enabled (usually provided by MKL)\\n  - NNPACK is enabled\\n  - CPU capability usage: AVX512\\n  - CUDA Runtime 11.1\\n  - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86\\n  - CuDNN 8.0.5\\n  - Magma 2.5.2\\n  - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.1, CUDNN_VERSION=8.0.5, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, \\n\', \'TorchVision\': \'0.11.0+cu111\', \'OpenCV\': \'4.6.0\', \'MMCV\': \'1.5.0\', \'MMDetection\': \'2.3.0+5462a60\', \'MMDetection Compiler\': \'GCC 7.5\', \'MMDetection CUDA Compiler\': \'11.1\'}"
#   }
# }
# custom_properties {
#   key: "seed"
#   value {
#     string_value: "666"
#   }
# }
# name: "Train-1"
# create_time_since_epoch: 1680748185535
# last_update_time_since_epoch: 1680748185535
# , id: 5
# type_id: 20
# properties {
#   key: "Context_ID"
#   value {
#     int_value: 4
#   }
# }
# properties {
#   key: "Context_Type"
#   value {
#     string_value: "active_learning/Cycle_Select"
#   }
# }
# properties {
#   key: "Execution"
#   value {
#     string_value: "[\'cycle_select.py\', \'configs/MIAOD-GRAY.py\', \'--work_directory\', \'work_dirs/test\', \'--cycle\', \'1\', \'--model\', \'work_dirs/test/cycle_1.pth\', \'--labeled\', \'work_dirs/test/X_L_1.npy\', \'--labeled_next\', \'work_dirs/test/X_L_2.npy\', \'--unselected\', \'work_dirs/test/X_U_2.npy\']"
#   }
# }
# properties {
#   key: "Git_End_Commit"
#   value {
#     string_value: ""
#   }
# }
# properties {
#   key: "Git_Repo"
#   value {
#     string_value: "/tmp/remote"
#   }
# }
# properties {
#   key: "Git_Start_Commit"
#   value {
#     string_value: "2684533ec003bc7ab828bc7223c98200a88dfa04"
#   }
# }
# properties {
#   key: "Pipeline_Type"
#   value {
#     string_value: "active_learning"
#   }
# }
# properties {
#   key: "Pipeline_id"
#   value {
#     int_value: 1
#   }
# }
# custom_properties {
#   key: "config"
#   value {
#     string_value: "<class \'mmcv.utils.config.Config\'>"
#   }
# }
# custom_properties {
#   key: "env"
#   value {
#     string_value: "{\'sys.platform\': \'linux\', \'Python\': \'3.8.15 (default, Nov 24 2022, 15:19:38) [GCC 11.2.0]\', \'CUDA available\': True, \'CUDA_HOME\': \'/usr/local/cuda\', \'NVCC\': \'Build cuda_11.1.TC455_06.29190527_0\', \'GPU 0,1,2,3,4,5,6,7\': \'Tesla V100-SXM2-16GB\', \'GCC\': \'gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0\', \'PyTorch\': \'1.10.0+cu111\', \'PyTorch compiling details\': \'PyTorch built with:\\n  - GCC 7.3\\n  - C++ Version: 201402\\n  - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications\\n  - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)\\n  - OpenMP 201511 (a.k.a. OpenMP 4.5)\\n  - LAPACK is enabled (usually provided by MKL)\\n  - NNPACK is enabled\\n  - CPU capability usage: AVX512\\n  - CUDA Runtime 11.1\\n  - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86\\n  - CuDNN 8.0.5\\n  - Magma 2.5.2\\n  - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.1, CUDNN_VERSION=8.0.5, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, \\n\', \'TorchVision\': \'0.11.0+cu111\', \'OpenCV\': \'4.6.0\', \'MMCV\': \'1.5.0\', \'MMDetection\': \'2.3.0+2684533\', \'MMDetection Compiler\': \'GCC 7.5\', \'MMDetection CUDA Compiler\': \'11.1\'}"
#   }
# }
# create_time_since_epoch: 1680748770584
# last_update_time_since_epoch: 1680748770584
# , id: 6
# type_id: 15
# properties {
#   key: "Context_ID"
#   value {
#     int_value: 3
#   }
# }
# properties {
#   key: "Context_Type"
#   value {
#     string_value: "active_learning/Train"
#   }
# }
# properties {
#   key: "Execution"
#   value {
#     string_value: "[\'cycle_train.py\', \'configs/MIAOD-GRAY.py\', \'--work_directory\', \'work_dirs/test\', \'--cycle\', \'2\', \'--labeled\', \'work_dirs/test/X_L_2.npy\', \'--unselected\', \'work_dirs/test/X_U_2.npy\', \'--model\', \'work_dirs/test/cycle_2.pth\']"
#   }
# }
# properties {
#   key: "Git_End_Commit"
#   value {
#     string_value: ""
#   }
# }
# properties {
#   key: "Git_Repo"
#   value {
#     string_value: "/tmp/remote"
#   }
# }
# properties {
#   key: "Git_Start_Commit"
#   value {
#     string_value: "2684533ec003bc7ab828bc7223c98200a88dfa04"
#   }
# }
# properties {
#   key: "Pipeline_Type"
#   value {
#     string_value: "active_learning"
#   }
# }
# properties {
#   key: "Pipeline_id"
#   value {
#     int_value: 1
#   }
# }
# custom_properties {
#   key: "env"
#   value {
#     string_value: "{\'sys.platform\': \'linux\', \'Python\': \'3.8.15 (default, Nov 24 2022, 15:19:38) [GCC 11.2.0]\', \'CUDA available\': True, \'CUDA_HOME\': \'/usr/local/cuda\', \'NVCC\': \'Build cuda_11.1.TC455_06.29190527_0\', \'GPU 0,1,2,3,4,5,6,7\': \'Tesla V100-SXM2-16GB\', \'GCC\': \'gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0\', \'PyTorch\': \'1.10.0+cu111\', \'PyTorch compiling details\': \'PyTorch built with:\\n  - GCC 7.3\\n  - C++ Version: 201402\\n  - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications\\n  - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)\\n  - OpenMP 201511 (a.k.a. OpenMP 4.5)\\n  - LAPACK is enabled (usually provided by MKL)\\n  - NNPACK is enabled\\n  - CPU capability usage: AVX512\\n  - CUDA Runtime 11.1\\n  - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86\\n  - CuDNN 8.0.5\\n  - Magma 2.5.2\\n  - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.1, CUDNN_VERSION=8.0.5, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, \\n\', \'TorchVision\': \'0.11.0+cu111\', \'OpenCV\': \'4.6.0\', \'MMCV\': \'1.5.0\', \'MMDetection\': \'2.3.0+2684533\', \'MMDetection Compiler\': \'GCC 7.5\', \'MMDetection CUDA Compiler\': \'11.1\'}"
#   }
# }
# custom_properties {
#   key: "seed"
#   value {
#     string_value: "666"
#   }
# }
# name: "Train-2"
# create_time_since_epoch: 1680749716832
# last_update_time_since_epoch: 1680749716832
# , id: 7
# type_id: 21
# properties {
#   key: "Context_ID"
#   value {
#     int_value: 4
#   }
# }
# properties {
#   key: "Context_Type"
#   value {
#     string_value: "active_learning/Cycle_Select"
#   }
# }
# properties {
#   key: "Execution"
#   value {
#     string_value: "[\'cycle_select.py\', \'configs/MIAOD-GRAY.py\', \'--work_directory\', \'work_dirs/test\', \'--cycle\', \'2\', \'--model\', \'work_dirs/test/cycle_2.pth\', \'--labeled\', \'work_dirs/test/X_L_2.npy\', \'--labeled_next\', \'work_dirs/test/X_L_3.npy\', \'--unselected\', \'work_dirs/test/X_U_3.npy\']"
#   }
# }
# properties {
#   key: "Git_End_Commit"
#   value {
#     string_value: ""
#   }
# }
# properties {
#   key: "Git_Repo"
#   value {
#     string_value: "/tmp/remote"
#   }
# }
# properties {
#   key: "Git_Start_Commit"
#   value {
#     string_value: "62c61d5acb2f080a5dc96305c57ee9f8845a6fbb"
#   }
# }
# properties {
#   key: "Pipeline_Type"
#   value {
#     string_value: "active_learning"
#   }
# }
# properties {
#   key: "Pipeline_id"
#   value {
#     int_value: 1
#   }
# }
# custom_properties {
#   key: "config"
#   value {
#     string_value: "<class \'mmcv.utils.config.Config\'>"
#   }
# }
# custom_properties {
#   key: "env"
#   value {
#     string_value: "{\'sys.platform\': \'linux\', \'Python\': \'3.8.15 (default, Nov 24 2022, 15:19:38) [GCC 11.2.0]\', \'CUDA available\': True, \'CUDA_HOME\': \'/usr/local/cuda\', \'NVCC\': \'Build cuda_11.1.TC455_06.29190527_0\', \'GPU 0,1,2,3,4,5,6,7\': \'Tesla V100-SXM2-16GB\', \'GCC\': \'gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0\', \'PyTorch\': \'1.10.0+cu111\', \'PyTorch compiling details\': \'PyTorch built with:\\n  - GCC 7.3\\n  - C++ Version: 201402\\n  - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications\\n  - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)\\n  - OpenMP 201511 (a.k.a. OpenMP 4.5)\\n  - LAPACK is enabled (usually provided by MKL)\\n  - NNPACK is enabled\\n  - CPU capability usage: AVX512\\n  - CUDA Runtime 11.1\\n  - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86\\n  - CuDNN 8.0.5\\n  - Magma 2.5.2\\n  - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.1, CUDNN_VERSION=8.0.5, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, \\n\', \'TorchVision\': \'0.11.0+cu111\', \'OpenCV\': \'4.6.0\', \'MMCV\': \'1.5.0\', \'MMDetection\': \'2.3.0+62c61d5\', \'MMDetection Compiler\': \'GCC 7.5\', \'MMDetection CUDA Compiler\': \'11.1\'}"
#   }
# }
# create_time_since_epoch: 1680750468103
# last_update_time_since_epoch: 1680750468103
# , id: 8
# type_id: 12
# properties {
#   key: "Context_ID"
#   value {
#     int_value: 6
#   }
# }
# properties {
#   key: "Context_Type"
#   value {
#     string_value: "active_learning_demo/Initial_select"
#   }
# }
# properties {
#   key: "Execution"
#   value {
#     string_value: "[\'initial_select.py\', \'configs/MIAOD-GRAY.py\', \'--work_directory\', \'work_dirs/test\', \'--labeled_next\', \'work_dirs/test/X_L_0.npy\', \'--unselected\', \'work_dirs/test/X_U_0.npy\']"
#   }
# }
# properties {
#   key: "Git_End_Commit"
#   value {
#     string_value: ""
#   }
# }
# properties {
#   key: "Git_Repo"
#   value {
#     string_value: "/tmp/remote"
#   }
# }
# properties {
#   key: "Git_Start_Commit"
#   value {
#     string_value: "e7ff966fc84c2d90499e023b50afdf8578e4cb38"
#   }
# }
# properties {
#   key: "Pipeline_Type"
#   value {
#     string_value: "active_learning_demo"
#   }
# }
# properties {
#   key: "Pipeline_id"
#   value {
#     int_value: 5
#   }
# }
# custom_properties {
#   key: "config"
#   value {
#     string_value: "Config (path: configs/MIAOD-GRAY.py): {\'model\': {\'type\': \'RetinaNet\', \'pretrained\': \'torchvision://resnet50\', \'backbone\': {\'type\': \'ResNet\', \'depth\': 50, \'num_stages\': 4, \'out_indices\': (0, 1, 2, 3), \'frozen_stages\': 1, \'norm_cfg\': {\'type\': \'BN\', \'requires_grad\': True}, \'norm_eval\': True, \'style\': \'pytorch\'}, \'neck\': {\'type\': \'FPN\', \'in_channels\': [256, 512, 1024, 2048], \'out_channels\': 256, \'start_level\': 1, \'add_extra_convs\': \'on_input\', \'num_outs\': 5}, \'bbox_head\': {\'type\': \'MIAODRetinaHead\', \'C\': 1, \'in_channels\': 256, \'stacked_convs\': 4, \'feat_channels\': 256, \'anchor_generator\': {\'type\': \'AnchorGenerator\', \'octave_base_scale\': 4, \'scales_per_octave\': 3, \'ratios\': [0.5, 1.0, 2.0], \'strides\': [8, 16, 32, 64, 128]}, \'bbox_coder\': {\'type\': \'DeltaXYWHBBoxCoder\', \'target_means\': [0.0, 0.0, 0.0, 0.0], \'target_stds\': [1.0, 1.0, 1.0, 1.0]}, \'FL\': {\'type\': \'FocalLoss\', \'use_sigmoid\': True, \'gamma\': 2.0, \'alpha\': 0.25, \'loss_weight\': 1.0}, \'SmoothL1\': {\'type\': \'L1Loss\', \'loss_weight\': 1.0}}}, \'train_cfg\': {\'assigner\': {\'type\': \'MaxIoUAssigner\', \'pos_iou_thr\': 0.5, \'neg_iou_thr\': 0.4, \'min_pos_iou\': 0, \'ignore_iof_thr\': -1}, \'allowed_border\': -1, \'pos_weight\': -1, \'debug\': False, \'param_lambda\': 0.5}, \'test_cfg\': {\'nms_pre\': 1000, \'min_bbox_size\': 0, \'score_thr\': 0.05, \'nms\': {\'type\': \'nms\', \'iou_threshold\': 0.5}, \'max_per_img\': 100}, \'theta_f_1\': [\'bbox_head.f_1_convs.0.conv.weight\', \'bbox_head.f_1_convs.0.conv.bias\', \'bbox_head.f_1_convs.1.conv.weight\', \'bbox_head.f_1_convs.1.conv.bias\', \'bbox_head.f_1_convs.2.conv.weight\', \'bbox_head.f_1_convs.2.conv.bias\', \'bbox_head.f_1_convs.3.conv.weight\', \'bbox_head.f_1_convs.3.conv.bias\', \'bbox_head.f_1_retina.weight\', \'bbox_head.f_1_retina.bias\'], \'theta_f_2\': [\'bbox_head.f_2_convs.0.conv.weight\', \'bbox_head.f_2_convs.0.conv.bias\', \'bbox_head.f_2_convs.1.conv.weight\', \'bbox_head.f_2_convs.1.conv.bias\', \'bbox_head.f_2_convs.2.conv.weight\', \'bbox_head.f_2_convs.2.conv.bias\', \'bbox_head.f_2_convs.3.conv.weight\', \'bbox_head.f_2_convs.3.conv.bias\', \'bbox_head.f_2_retina.weight\', \'bbox_head.f_2_retina.bias\'], \'data_root\': \'hdcdatasets/\', \'dataset_type\': \'HDCDataset\', \'img_norm_cfg\': {\'mean\': [123.675, 123.675, 123.675], \'std\': [58.395, 58.395, 58.395], \'to_rgb\': True}, \'train_pipeline\': [{\'type\': \'LoadImageFromFile\'}, {\'type\': \'LoadAnnotations\', \'with_bbox\': True}, {\'type\': \'Resize\', \'img_scale\': (960, 960), \'keep_ratio\': True}, {\'type\': \'RandomFlip\', \'flip_ratio\': 0.5}, {\'type\': \'RandomFlip\', \'flip_ratio\': 0.5, \'direction\': \'vertical\'}, {\'type\': \'Normalize\', \'mean\': [123.675, 123.675, 123.675], \'std\': [58.395, 58.395, 58.395], \'to_rgb\': True}, {\'type\': \'Pad\', \'size_divisor\': 32}, {\'type\': \'DefaultFormatBundle\'}, {\'type\': \'Collect\', \'keys\': [\'img\', \'gt_bboxes\', \'gt_labels\']}], \'test_pipeline\': [{\'type\': \'LoadImageFromFile\'}, {\'type\': \'MultiScaleFlipAug\', \'img_scale\': (960, 960), \'flip\': False, \'transforms\': [{\'type\': \'Resize\', \'keep_ratio\': True}, {\'type\': \'RandomFlip\', \'flip_ratio\': 0.5}, {\'type\': \'RandomFlip\', \'flip_ratio\': 0.5, \'direction\': \'vertical\'}, {\'type\': \'Normalize\', \'mean\': [123.675, 123.675, 123.675], \'std\': [58.395, 58.395, 58.395], \'to_rgb\': True}, {\'type\': \'Pad\', \'size_divisor\': 32}, {\'type\': \'ImageToTensor\', \'keys\': [\'img\']}, {\'type\': \'Collect\', \'keys\': [\'img\']}]}], \'data\': {\'samples_per_gpu\': 8, \'workers_per_gpu\': 8, \'train\': {\'type\': \'RepeatDataset\', \'times\': 3, \'dataset\': {\'type\': \'HDCDataset\', \'ann_file\': [\'hdcdatasets/hdc_single/ImageSets/Main/trainval.txt\'], \'img_prefix\': [\'hdcdatasets/hdc_single/\'], \'pipeline\': [{\'type\': \'LoadImageFromFile\'}, {\'type\': \'LoadAnnotations\ ...
#   }
# }
# custom_properties {
#   key: "env"
#   value {
#     string_value: "{\'sys.platform\': \'linux\', \'Python\': \'3.8.15 (default, Nov 24 2022, 15:19:38) [GCC 11.2.0]\', \'CUDA available\': True, \'CUDA_HOME\': \'/usr/local/cuda\', \'NVCC\': \'Build cuda_11.1.TC455_06.29190527_0\', \'GPU 0,1,2,3,4,5,6,7\': \'Tesla V100-SXM2-16GB\', \'GCC\': \'gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0\', \'PyTorch\': \'1.10.0+cu111\', \'PyTorch compiling details\': \'PyTorch built with:\\n  - GCC 7.3\\n  - C++ Version: 201402\\n  - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications\\n  - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)\\n  - OpenMP 201511 (a.k.a. OpenMP 4.5)\\n  - LAPACK is enabled (usually provided by MKL)\\n  - NNPACK is enabled\\n  - CPU capability usage: AVX512\\n  - CUDA Runtime 11.1\\n  - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86\\n  - CuDNN 8.0.5\\n  - Magma 2.5.2\\n  - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.1, CUDNN_VERSION=8.0.5, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, \\n\', \'TorchVision\': \'0.11.0+cu111\', \'OpenCV\': \'4.6.0\', \'MMCV\': \'1.5.0\', \'MMDetection\': \'2.3.0+e7ff966\', \'MMDetection Compiler\': \'GCC 7.5\', \'MMDetection CUDA Compiler\': \'11.1\'}"
#   }
# }
# create_time_since_epoch: 1680788228451
# last_update_time_since_epoch: 1680788228451
# , id: 9
# type_id: 12
# properties {
#   key: "Context_ID"
#   value {
#     int_value: 6
#   }
# }
# properties {
#   key: "Context_Type"
#   value {
#     string_value: "active_learning_demo/Initial_select"
#   }
# }
# properties {
#   key: "Execution"
#   value {
#     string_value: "[\'initial_select.py\', \'configs/MIAOD-GRAY.py\', \'--work_directory\', \'work_dirs/test\', \'--labeled_next\', \'work_dirs/test/X_L_0.npy\', \'--unselected\', \'work_dirs/test/X_U_0.npy\']"
#   }
# }
# properties {
#   key: "Git_End_Commit"
#   value {
#     string_value: ""
#   }
# }
# properties {
#   key: "Git_Repo"
#   value {
#     string_value: "/tmp/remote"
#   }
# }
# properties {
#   key: "Git_Start_Commit"
#   value {
#     string_value: "e7ff966fc84c2d90499e023b50afdf8578e4cb38"
#   }
# }
# properties {
#   key: "Pipeline_Type"
#   value {
#     string_value: "active_learning_demo"
#   }
# }
# properties {
#   key: "Pipeline_id"
#   value {
#     int_value: 5
#   }
# }
# custom_properties {
#   key: "config"
#   value {
#     string_value: "Config (path: configs/MIAOD-GRAY.py): {\'model\': {\'type\': \'RetinaNet\', \'pretrained\': \'torchvision://resnet50\', \'backbone\': {\'type\': \'ResNet\', \'depth\': 50, \'num_stages\': 4, \'out_indices\': (0, 1, 2, 3), \'frozen_stages\': 1, \'norm_cfg\': {\'type\': \'BN\', \'requires_grad\': True}, \'norm_eval\': True, \'style\': \'pytorch\'}, \'neck\': {\'type\': \'FPN\', \'in_channels\': [256, 512, 1024, 2048], \'out_channels\': 256, \'start_level\': 1, \'add_extra_convs\': \'on_input\', \'num_outs\': 5}, \'bbox_head\': {\'type\': \'MIAODRetinaHead\', \'C\': 1, \'in_channels\': 256, \'stacked_convs\': 4, \'feat_channels\': 256, \'anchor_generator\': {\'type\': \'AnchorGenerator\', \'octave_base_scale\': 4, \'scales_per_octave\': 3, \'ratios\': [0.5, 1.0, 2.0], \'strides\': [8, 16, 32, 64, 128]}, \'bbox_coder\': {\'type\': \'DeltaXYWHBBoxCoder\', \'target_means\': [0.0, 0.0, 0.0, 0.0], \'target_stds\': [1.0, 1.0, 1.0, 1.0]}, \'FL\': {\'type\': \'FocalLoss\', \'use_sigmoid\': True, \'gamma\': 2.0, \'alpha\': 0.25, \'loss_weight\': 1.0}, \'SmoothL1\': {\'type\': \'L1Loss\', \'loss_weight\': 1.0}}}, \'train_cfg\': {\'assigner\': {\'type\': \'MaxIoUAssigner\', \'pos_iou_thr\': 0.5, \'neg_iou_thr\': 0.4, \'min_pos_iou\': 0, \'ignore_iof_thr\': -1}, \'allowed_border\': -1, \'pos_weight\': -1, \'debug\': False, \'param_lambda\': 0.5}, \'test_cfg\': {\'nms_pre\': 1000, \'min_bbox_size\': 0, \'score_thr\': 0.05, \'nms\': {\'type\': \'nms\', \'iou_threshold\': 0.5}, \'max_per_img\': 100}, \'theta_f_1\': [\'bbox_head.f_1_convs.0.conv.weight\', \'bbox_head.f_1_convs.0.conv.bias\', \'bbox_head.f_1_convs.1.conv.weight\', \'bbox_head.f_1_convs.1.conv.bias\', \'bbox_head.f_1_convs.2.conv.weight\', \'bbox_head.f_1_convs.2.conv.bias\', \'bbox_head.f_1_convs.3.conv.weight\', \'bbox_head.f_1_convs.3.conv.bias\', \'bbox_head.f_1_retina.weight\', \'bbox_head.f_1_retina.bias\'], \'theta_f_2\': [\'bbox_head.f_2_convs.0.conv.weight\', \'bbox_head.f_2_convs.0.conv.bias\', \'bbox_head.f_2_convs.1.conv.weight\', \'bbox_head.f_2_convs.1.conv.bias\', \'bbox_head.f_2_convs.2.conv.weight\', \'bbox_head.f_2_convs.2.conv.bias\', \'bbox_head.f_2_convs.3.conv.weight\', \'bbox_head.f_2_convs.3.conv.bias\', \'bbox_head.f_2_retina.weight\', \'bbox_head.f_2_retina.bias\'], \'data_root\': \'hdcdatasets/\', \'dataset_type\': \'HDCDataset\', \'img_norm_cfg\': {\'mean\': [123.675, 123.675, 123.675], \'std\': [58.395, 58.395, 58.395], \'to_rgb\': True}, \'train_pipeline\': [{\'type\': \'LoadImageFromFile\'}, {\'type\': \'LoadAnnotations\', \'with_bbox\': True}, {\'type\': \'Resize\', \'img_scale\': (960, 960), \'keep_ratio\': True}, {\'type\': \'RandomFlip\', \'flip_ratio\': 0.5}, {\'type\': \'RandomFlip\', \'flip_ratio\': 0.5, \'direction\': \'vertical\'}, {\'type\': \'Normalize\', \'mean\': [123.675, 123.675, 123.675], \'std\': [58.395, 58.395, 58.395], \'to_rgb\': True}, {\'type\': \'Pad\', \'size_divisor\': 32}, {\'type\': \'DefaultFormatBundle\'}, {\'type\': \'Collect\', \'keys\': [\'img\', \'gt_bboxes\', \'gt_labels\']}], \'test_pipeline\': [{\'type\': \'LoadImageFromFile\'}, {\'type\': \'MultiScaleFlipAug\', \'img_scale\': (960, 960), \'flip\': False, \'transforms\': [{\'type\': \'Resize\', \'keep_ratio\': True}, {\'type\': \'RandomFlip\', \'flip_ratio\': 0.5}, {\'type\': \'RandomFlip\', \'flip_ratio\': 0.5, \'direction\': \'vertical\'}, {\'type\': \'Normalize\', \'mean\': [123.675, 123.675, 123.675], \'std\': [58.395, 58.395, 58.395], \'to_rgb\': True}, {\'type\': \'Pad\', \'size_divisor\': 32}, {\'type\': \'ImageToTensor\', \'keys\': [\'img\']}, {\'type\': \'Collect\', \'keys\': [\'img\']}]}], \'data\': {\'samples_per_gpu\': 8, \'workers_per_gpu\': 8, \'train\': {\'type\': \'RepeatDataset\', \'times\': 3, \'dataset\': {\'type\': \'HDCDataset\', \'ann_file\': [\'hdcdatasets/hdc_single/ImageSets/Main/trainval.txt\'], \'img_prefix\': [\'hdcdatasets/hdc_single/\'], \'pipeline\': [{\'type\': \'LoadImageFromFile\'}, {\'type\': \'LoadAnnotations\ ...
#   }
# }
# custom_properties {
#   key: "env"
#   value {
#     string_value: "{\'sys.platform\': \'linux\', \'Python\': \'3.8.15 (default, Nov 24 2022, 15:19:38) [GCC 11.2.0]\', \'CUDA available\': True, \'CUDA_HOME\': \'/usr/local/cuda\', \'NVCC\': \'Build cuda_11.1.TC455_06.29190527_0\', \'GPU 0,1,2,3,4,5,6,7\': \'Tesla V100-SXM2-16GB\', \'GCC\': \'gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0\', \'PyTorch\': \'1.10.0+cu111\', \'PyTorch compiling details\': \'PyTorch built with:\\n  - GCC 7.3\\n  - C++ Version: 201402\\n  - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications\\n  - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)\\n  - OpenMP 201511 (a.k.a. OpenMP 4.5)\\n  - LAPACK is enabled (usually provided by MKL)\\n  - NNPACK is enabled\\n  - CPU capability usage: AVX512\\n  - CUDA Runtime 11.1\\n  - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86\\n  - CuDNN 8.0.5\\n  - Magma 2.5.2\\n  - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.1, CUDNN_VERSION=8.0.5, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, \\n\', \'TorchVision\': \'0.11.0+cu111\', \'OpenCV\': \'4.6.0\', \'MMCV\': \'1.5.0\', \'MMDetection\': \'2.3.0+e7ff966\', \'MMDetection Compiler\': \'GCC 7.5\', \'MMDetection CUDA Compiler\': \'11.1\'}"
#   }
# }
# create_time_since_epoch: 1680788477262
# last_update_time_since_epoch: 1680788477262
# , id: 10
# type_id: 22
# properties {
#   key: "Context_ID"
#   value {
#     int_value: 7
#   }
# }
# properties {
#   key: "Context_Type"
#   value {
#     string_value: "active_learning_demo/Train"
#   }
# }
# properties {
#   key: "Execution"
#   value {
#     string_value: "[\'cycle_train.py\', \'configs/MIAOD-GRAY.py\', \'--work_directory\', \'work_dirs/test\', \'--cycle\', \'0\', \'--labeled\', \'work_dirs/test/X_L_0.npy\', \'--unselected\', \'work_dirs/test/X_U_0.npy\', \'--model\', \'work_dirs/test/cycle_0.pth\']"
#   }
# }
# properties {
#   key: "Git_End_Commit"
#   value {
#     string_value: ""
#   }
# }
# properties {
#   key: "Git_Repo"
#   value {
#     string_value: "/tmp/remote"
#   }
# }
# properties {
#   key: "Git_Start_Commit"
#   value {
#     string_value: "e7ff966fc84c2d90499e023b50afdf8578e4cb38"
#   }
# }
# properties {
#   key: "Pipeline_Type"
#   value {
#     string_value: "active_learning_demo"
#   }
# }
# properties {
#   key: "Pipeline_id"
#   value {
#     int_value: 5
#   }
# }
# custom_properties {
#   key: "env"
#   value {
#     string_value: "{\'sys.platform\': \'linux\', \'Python\': \'3.8.15 (default, Nov 24 2022, 15:19:38) [GCC 11.2.0]\', \'CUDA available\': True, \'CUDA_HOME\': \'/usr/local/cuda\', \'NVCC\': \'Build cuda_11.1.TC455_06.29190527_0\', \'GPU 0,1,2,3,4,5,6,7\': \'Tesla V100-SXM2-16GB\', \'GCC\': \'gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0\', \'PyTorch\': \'1.10.0+cu111\', \'PyTorch compiling details\': \'PyTorch built with:\\n  - GCC 7.3\\n  - C++ Version: 201402\\n  - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications\\n  - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)\\n  - OpenMP 201511 (a.k.a. OpenMP 4.5)\\n  - LAPACK is enabled (usually provided by MKL)\\n  - NNPACK is enabled\\n  - CPU capability usage: AVX512\\n  - CUDA Runtime 11.1\\n  - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86\\n  - CuDNN 8.0.5\\n  - Magma 2.5.2\\n  - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.1, CUDNN_VERSION=8.0.5, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, \\n\', \'TorchVision\': \'0.11.0+cu111\', \'OpenCV\': \'4.6.0\', \'MMCV\': \'1.5.0\', \'MMDetection\': \'2.3.0+e7ff966\', \'MMDetection Compiler\': \'GCC 7.5\', \'MMDetection CUDA Compiler\': \'11.1\'}"
#   }
# }
# custom_properties {
#   key: "seed"
#   value {
#     string_value: "666"
#   }
# }
# name: "Train-0"
# create_time_since_epoch: 1680788580946
# last_update_time_since_epoch: 1680788580946
# ]

# %%
import pandas as pd
from cmflib import cmfquery

# %% [markdown]
# ### Initialize the library and get all the stages in the pipeline
# Point the library to the metadata file. <br>
# The `get_pipeline_stages` call point to the different stages in the pipeline.

# %%
query = cmfquery.CmfQuery("./mlmd")
pipelines = query.get_pipeline_names()
stages = query.get_pipeline_stages(pipelines[0])
display(stages)
# Out:
# ['active_learning/Initial_select',
#  'active_learning/Train',
#  'active_learning/Cycle_Select']

# %% [markdown]
# ### Query the Executions in each stage

# %%
for stage in stages:
    executions = query.get_all_executions_in_stage(stage)
    print(f"Displaying execution for stage {stage}")
    display(executions)
# Out:
# Displaying execution for stage active_learning/Initial_select
#    Context_ID                    Context_Type  \
# 0           2  active_learning/Initial_select
#
#                                            Execution Git_End_Commit  \
# 0  ['initial_select.py', 'configs/MIAOD-GRAY.py',...
#
#       Git_Repo                          Git_Start_Commit    Pipeline_Type  \
# 0  /tmp/remote  62bc1f873091a1ddee42228601857e722f05b92a  active_learning
#
#    Pipeline_id                                             config  \
# 0            1  Config (path: configs/MIAOD-GRAY.py): {'model'...
#
#                                                  env  id
# 0  {'sys.platform': 'linux', 'Python': '3.8.15 (d...   1
# Displaying execution for stage active_learning/Train
#    Context_ID           Context_Type  \
# 0           3  active_learning/Train
# 1           3  active_learning/Train
# 2           3  active_learning/Train
#
#                                            Execution Git_End_Commit  \
# 0  ['cycle_train.py', 'configs/MIAOD-GRAY.py', '-...
# 1  ['cycle_train.py', 'configs/MIAOD-GRAY.py', '-...
# 2  ['cycle_train.py', 'configs/MIAOD-GRAY.py', '-...
#
#       Git_Repo                          Git_Start_Commit    Pipeline_Type  \
# 0  /tmp/remote  2684533ec003bc7ab828bc7223c98200a88dfa04  active_learning
# 1  /tmp/remote  5462a60d81b5b72eeb60c99b8decde79a63b4c04  active_learning
# 2  /tmp/remote  62bc1f873091a1ddee42228601857e722f05b92a  active_learning
#
#    Pipeline_id                                                env  id seed
# 0            1  {'sys.platform': 'linux', 'Python': '3.8.15 (d...   6  666
# 1            1  {'sys.platform': 'linux', 'Python': '3.8.15 (d...   4  666
# 2            1  {'sys.platform': 'linux', 'Python': '3.8.15 (d...   2  666
# Displaying execution for stage active_learning/Cycle_Select
#    Context_ID                  Context_Type  \
# 0           4  active_learning/Cycle_Select
# 1           4  active_learning/Cycle_Select
# 2           4  active_learning/Cycle_Select
#
#                                            Execution Git_End_Commit  \
# 0  ['cycle_select.py', 'configs/MIAOD-GRAY.py', '...
# 1  ['cycle_select.py', 'configs/MIAOD-GRAY.py', '...
# 2  ['cycle_select.py', 'configs/MIAOD-GRAY.py', '...
#
#       Git_Repo                          Git_Start_Commit    Pipeline_Type  \
# 0  /tmp/remote  62c61d5acb2f080a5dc96305c57ee9f8845a6fbb  active_learning
# 1  /tmp/remote  2684533ec003bc7ab828bc7223c98200a88dfa04  active_learning
# 2  /tmp/remote  5462a60d81b5b72eeb60c99b8decde79a63b4c04  active_learning
#
#    Pipeline_id                              config  \
# 0            1  <class 'mmcv.utils.config.Config'>
# 1            1  <class 'mmcv.utils.config.Config'>
# 2            1  <class 'mmcv.utils.config.Config'>
#
#                                                  env  id
# 0  {'sys.platform': 'linux', 'Python': '3.8.15 (d...   7
# 1  {'sys.platform': 'linux', 'Python': '3.8.15 (d...   5
# 2  {'sys.platform': 'linux', 'Python': '3.8.15 (d...   3

# %% [markdown]
# ### Get all  artifacts of an execution.
# <b>input parameter - execution_id</b><br>
# <b>output parameter - artifacts</b><br>

# %%
executions = query.get_all_executions_in_stage(stages[0])
print(f"Displaying the artifacts for execution with id {executions.iloc[0]['id']} belonging to {stages[0]}")
artifacts = query.get_all_artifacts_for_execution(executions.iloc[0]["id"])
display(artifacts)
# Out:
# Displaying the artifacts for execution with id 1 belonging to active_learning/Initial_select
#   Background_no_bounding_boxes                                Commit  \
# 0                         True  5ccd6cefba4a460ea5a9edad75a1e4af.dir
# 1                          NaN      84e52a5da234c849655b276561889960
# 2                          NaN      0eef7540aa910839ad064798927b5b78
# 3                          NaN      60c0ebf589d21493fcd7ee6744558063
#
#                                             Remote  create_time_since_epoch  \
# 0                                              NaN            1680746922564
# 1                                              NaN            1680746925160
# 2  /tmp/myremote/0e/ef7540aa910839ad064798927b5b78            1680746928083
# 3                                              NaN            1680746930631
#
#   cycle   event     git_repo gray_scale  id labeled  \
# 0   NaN   INPUT  /tmp/remote       True   1     NaN
# 1     0  OUTPUT  /tmp/remote        NaN   2    True
# 2   NaN  OUTPUT  /tmp/remote        NaN   3     NaN
# 3     0  OUTPUT  /tmp/remote        NaN   4   False
#
#    last_update_time_since_epoch mean median  \
# 0                 1680788260710  NaN    NaN
# 1                 1680788263123  NaN    NaN
# 2                 1680746928083   -1     -1
# 3                 1680788518007  NaN    NaN
#
#                                                 name       type  \
# 0  hdcdatasets/hdc_single/JPEGImages:5ccd6cefba4a...    Dataset
# 1  work_dirs/test/X_L_0.npy:84e52a5da234c849655b2...      numpy
# 2           slice-0:0eef7540aa910839ad064798927b5b78  Dataslice
# 3  work_dirs/test/X_U_0.npy:60c0ebf589d21493fcd7e...      numpy
#
#                                     uri  \
# 0  5ccd6cefba4a460ea5a9edad75a1e4af.dir
# 1      84e52a5da234c849655b276561889960
# 2      0eef7540aa910839ad064798927b5b78
# 3      60c0ebf589d21493fcd7ee6744558063
#
#                                                  url
# 0  active_learning:/tmp/myremote/5c/cd6cefba4a460...
# 1  active_learning:/tmp/myremote/84/e52a5da234c84...
# 2                                                NaN
# 3  active_learning:/tmp/myremote/60/c0ebf589d2149...

# %% [markdown]
# ### Get all executions for an artifact (pass the artifact full name as the input parameter)

# %%
#Provide the artifact in name:hash format
artifacts = query.get_all_artifacts_for_execution(executions.iloc[0]['id'])
for index, art in artifacts.iterrows():
    if art["event"] == "INPUT":
        artifact_name = art["name"]
        break
linked = query.get_all_executions_for_artifact(artifact_name)
display(linked)
# Out:
#     Type  execution_id execution_name              pipeline  \
# 0  INPUT             1                      active_learning
# 1  INPUT             8                 active_learning_demo
# 2  INPUT             9                 active_learning_demo
#
#                                  stage
# 0       active_learning/Initial_select
# 1  active_learning_demo/Initial_select
# 2  active_learning_demo/Initial_select

# %% [markdown]
# ### Get all the parent artifacts of an artifact. Provides the artifact lineage chain

# %%
artifacts = query.get_all_artifacts_for_execution(2)
for index, art in artifacts.iterrows():
    if art["event"] == "OUTPUT":
        artifact_name = art["name"]
        break
print(f"Parent artifact of {artifact_name}")
linked = query.get_all_parent_artifacts(artifact_name)
display(linked)
# Out:
# Parent artifact of metrics_1:34d783f5cd5f76dcd4edb6d63779c07c:2:47ae49f0-d420-11ed-a37a-d4c9efcecfde
#   Background_no_bounding_boxes                                Commit  \
# 0                          NaN      84e52a5da234c849655b276561889960
# 1                          NaN      60c0ebf589d21493fcd7ee6744558063
# 2                         True  5ccd6cefba4a460ea5a9edad75a1e4af.dir
# 3                          NaN      0eef7540aa910839ad064798927b5b78
#
#                                             Remote  create_time_since_epoch  \
# 0                                              NaN            1680746925160
# 1                                              NaN            1680746930631
# 2                                              NaN            1680746922564
# 3  /tmp/myremote/0e/ef7540aa910839ad064798927b5b78            1680746928083
#
#   cycle     git_repo gray_scale  id labeled  last_update_time_since_epoch  \
# 0     0  /tmp/remote        NaN   2    True                 1680788263123
# 1     0  /tmp/remote        NaN   4   False                 1680788518007
# 2   NaN  /tmp/remote       True   1     NaN                 1680788260710
# 3   NaN  /tmp/remote        NaN   3     NaN                 1680746928083
#
#   mean median                                               name       type  \
# 0  NaN    NaN  work_dirs/test/X_L_0.npy:84e52a5da234c849655b2...      numpy
# 1  NaN    NaN  work_dirs/test/X_U_0.npy:60c0ebf589d21493fcd7e...      numpy
# 2  NaN    NaN  hdcdatasets/hdc_single/JPEGImages:5ccd6cefba4a...    Dataset
# 3   -1     -1           slice-0:0eef7540aa910839ad064798927b5b78  Dataslice
#
#                                     uri  \
# 0      84e52a5da234c849655b276561889960
# 1      60c0ebf589d21493fcd7ee6744558063
# 2  5ccd6cefba4a460ea5a9edad75a1e4af.dir
# 3      0eef7540aa910839ad064798927b5b78
#
#                                                  url
# 0  active_learning:/tmp/myremote/84/e52a5da234c84...
# 1  active_learning:/tmp/myremote/60/c0ebf589d2149...
# 2  active_learning:/tmp/myremote/5c/cd6cefba4a460...
# 3                                                NaN

# %% [markdown]
# ###  Get all  child artifacts of an artifact. It provides the lineage chain of successors

# %%
artifacts = query.get_all_artifacts_for_execution(1)
for index, art in artifacts.iterrows():
    if art["event"] == "INPUT":
        artifact_name = art["name"]
        break

print(f"Child artifact of {artifact_name}")
linked = query.get_all_child_artifacts(artifact_name)
display(linked)
# Out:
# Child artifact of hdcdatasets/hdc_single/JPEGImages:5ccd6cefba4a460ea5a9edad75a1e4af.dir
#                               Commit       Name  \
# 0   84e52a5da234c849655b276561889960        NaN
# 1   0eef7540aa910839ad064798927b5b78        NaN
# 2   60c0ebf589d21493fcd7ee6744558063        NaN
# 3   34d783f5cd5f76dcd4edb6d63779c07c  metrics_1
# 4                                NaN        NaN
# 5   8f328f08a1cc232c1aaf92a7ec038405  metrics_1
# 6   43b7ae48099741419a1cf520b8ac8fae        NaN
# 7   13840834c91f4a2f1925dc7cd6949688  metrics_1
# 8                                NaN        NaN
# 9   16de902f650a94db87d7c83f74b87eef  metrics_1
# 10  94f49728e04dbde790b46c7c4d462d88        NaN
# 11  c534ea8d9bb64a9b68802334cda12d11        NaN
# 12  7013dd0522de32928fb216366458140f        NaN
# 13  3eef0041cb7851dc19f5509201246d18        NaN
# 14  80346286df44b7e2213cee9516bb6e64  metrics_1
# 15                               NaN        NaN
# 16  388f94930ac804605b96ba8127d214ef  metrics_1
# 17  6b4c9484d65e6357b694125fe9bd842e        NaN
# 18  60632314f146caeefa4622bd38ebfbd7        NaN
# 19  4b3e007d73b2ead9daaa058f365b412a        NaN
# 20  6267c2069f4b3e5aea8ee2f8c012c4de        NaN
# 21  fd4f4f1a73f77d23be7ae7c7f72c834a  metrics_1
# 22                               NaN        NaN
# 23  1f2b2a69ba0641501e62b63e8ef389f5  metrics_1
# 24  ebd5ec89297061df40174a5db5c74ec2        NaN
# 25  92a6915b498ac2e6e59777e0043cd004        NaN
# 26  f074bd626265edd57175a8a5ecc0f081        NaN
# 27  e95c79451b72ff42ee4a168c84cea684        NaN
#
#                                              Remote  \
# 0                                               NaN
# 1   /tmp/myremote/0e/ef7540aa910839ad064798927b5b78
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13  /tmp/myremote/3e/ef0041cb7851dc19f5509201246d18
# 14                                              NaN
# 15                                              NaN
# 16                                              NaN
# 17                                              NaN
# 18                                              NaN
# 19                                              NaN
# 20  /tmp/myremote/62/67c2069f4b3e5aea8ee2f8c012c4de
# 21                                              NaN
# 22                                              NaN
# 23                                              NaN
# 24                                              NaN
# 25                                              NaN
# 26                                              NaN
# 27  /tmp/myremote/e9/5c79451b72ff42ee4a168c84cea684
#
#                                              backbone  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  {'type': 'ResNet', 'depth': 50, 'num_stages': ...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
#
#                                             bbox_head  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  {'type': 'MIAODRetinaHead', 'C': 1, 'in_channe...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
#
#     create_time_since_epoch cycle     git_repo  id labeled  ...  \
# 0             1680746925160     0  /tmp/remote   2    True  ...
# 1             1680746928083   NaN  /tmp/remote   3     NaN  ...
# 2             1680746930631     0  /tmp/remote   4   False  ...
# 3             1680747062501   NaN          NaN   5     NaN  ...
# 4             1680747399557   NaN          NaN   6     NaN  ...
# 5             1680747401867   NaN          NaN   7     NaN  ...
# 6             1680747406594   NaN          NaN   8     NaN  ...
# 7             1680788698779   NaN          NaN  26     NaN  ...
# 8             1680789037554   NaN          NaN  27     NaN  ...
# 9             1680789039975   NaN          NaN  28     NaN  ...
# 10            1680789044747   NaN          NaN  29     NaN  ...
# 11            1680748083890     1  /tmp/remote   9    True  ...
# 12            1680748086851     1  /tmp/remote  10   False  ...
# 13            1680748089601   NaN  /tmp/remote  11     NaN  ...
# 14            1680748353147   NaN          NaN  12     NaN  ...
# 15            1680748739364   NaN          NaN  13     NaN  ...
# 16            1680748741753   NaN          NaN  14     NaN  ...
# 17            1680748746546   NaN          NaN  15     NaN  ...
# 18            1680749411507     2  /tmp/remote  16    True  ...
# 19            1680749414636     2  /tmp/remote  17   False  ...
# 20            1680749417271   NaN  /tmp/remote  18     NaN  ...
# 21            1680749936798   NaN          NaN  19     NaN  ...
# 22            1680750378221   NaN          NaN  20     NaN  ...
# 23            1680750380494   NaN          NaN  21     NaN  ...
# 24            1680750385308   NaN          NaN  22     NaN  ...
# 25            1680751107274     3  /tmp/remote  23     NaN  ...
# 26            1680751110224     3  /tmp/remote  24     NaN  ...
# 27            1680751113150   NaN  /tmp/remote  25     NaN  ...
#
#                                    metrics_name model_framework model_name  \
# 0                                           NaN             NaN        NaN
# 1                                           NaN             NaN        NaN
# 2                                           NaN             NaN        NaN
# 3                                           NaN             NaN        NaN
# 4    mAP:1094e374-d421-11ed-a37a-d4c9efcecfde:2             NaN        NaN
# 5                                           NaN             NaN        NaN
# 6                                           NaN           mmdet   resnet50
# 7                                           NaN             NaN        NaN
# 8   mAP:02c34248-d482-11ed-a37a-d4c9efcecfde:10             NaN        NaN
# 9                                           NaN             NaN        NaN
# 10                                          NaN           mmdet   resnet50
# 11                                          NaN             NaN        NaN
# 12                                          NaN             NaN        NaN
# 13                                          NaN             NaN        NaN
# 14                                          NaN             NaN        NaN
# 15   mAP:2f2b64fe-d424-11ed-a37a-d4c9efcecfde:4             NaN        NaN
# 16                                          NaN             NaN        NaN
# 17                                          NaN           mmdet   resnet50
# 18                                          NaN             NaN        NaN
# 19                                          NaN             NaN        NaN
# 20                                          NaN             NaN        NaN
# 21                                          NaN             NaN        NaN
# 22   mAP:0001291c-d428-11ed-a37a-d4c9efcecfde:6             NaN        NaN
# 23                                          NaN             NaN        NaN
# 24                                          NaN           mmdet   resnet50
# 25                                          NaN             NaN        NaN
# 26                                          NaN             NaN        NaN
# 27                                          NaN             NaN        NaN
#
#    model_type                                               name  \
# 0         NaN  work_dirs/test/X_L_0.npy:84e52a5da234c849655b2...
# 1         NaN           slice-0:0eef7540aa910839ad064798927b5b78
# 2         NaN  work_dirs/test/X_U_0.npy:60c0ebf589d21493fcd7e...
# 3         NaN  metrics_1:34d783f5cd5f76dcd4edb6d63779c07c:2:4...
# 4         NaN         mAP:1094e374-d421-11ed-a37a-d4c9efcecfde:2
# 5         NaN  metrics_1:8f328f08a1cc232c1aaf92a7ec038405:2:1...
# 6   RetinaNet  work_dirs/test/cycle_0.pth:43b7ae48099741419a1...
# 7         NaN  metrics_1:13840834c91f4a2f1925dc7cd6949688:10:...
# 8         NaN        mAP:02c34248-d482-11ed-a37a-d4c9efcecfde:10
# 9         NaN  metrics_1:16de902f650a94db87d7c83f74b87eef:10:...
# 10  RetinaNet  work_dirs/test/cycle_0.pth:94f49728e04dbde790b...
# 11        NaN  work_dirs/test/X_L_1.npy:c534ea8d9bb64a9b68802...
# 12        NaN  work_dirs/test/X_U_1.npy:7013dd0522de32928fb21...
# 13        NaN           slice_1:3eef0041cb7851dc19f5509201246d18
# 14        NaN  metrics_1:80346286df44b7e2213cee9516bb6e64:4:4...
# 15        NaN         mAP:2f2b64fe-d424-11ed-a37a-d4c9efcecfde:4
# 16        NaN  metrics_1:388f94930ac804605b96ba8127d214ef:4:3...
# 17  RetinaNet  work_dirs/test/cycle_1.pth:6b4c9484d65e6357b69...
# 18        NaN  work_dirs/test/X_L_2.npy:60632314f146caeefa462...
# 19        NaN  work_dirs/test/X_U_2.npy:4b3e007d73b2ead9daaa0...
# 20        NaN           slice_2:6267c2069f4b3e5aea8ee2f8c012c4de
# 21        NaN  metrics_1:fd4f4f1a73f77d23be7ae7c7f72c834a:6:f...
# 22        NaN         mAP:0001291c-d428-11ed-a37a-d4c9efcecfde:6
# 23        NaN  metrics_1:1f2b2a69ba0641501e62b63e8ef389f5:6:0...
# 24  RetinaNet  work_dirs/test/cycle_2.pth:ebd5ec89297061df401...
# 25        NaN  work_dirs/test/X_L_3.npy:92a6915b498ac2e6e5977...
# 26        NaN  work_dirs/test/X_U_3.npy:f074bd626265edd57175a...
# 27        NaN           slice_3:e95c79451b72ff42ee4a168c84cea684
#
#                                                  neck          type  \
# 0                                                 NaN         numpy
# 1                                                 NaN     Dataslice
# 2                                                 NaN         numpy
# 3                                                 NaN  Step_Metrics
# 4                                                 NaN       Metrics
# 5                                                 NaN  Step_Metrics
# 6                                                 NaN         Model
# 7                                                 NaN  Step_Metrics
# 8                                                 NaN       Metrics
# 9                                                 NaN  Step_Metrics
# 10  {'type': 'FPN', 'in_channels': [256, 512, 1024...     RetinaNet
# 11                                                NaN         numpy
# 12                                                NaN         numpy
# 13                                                NaN     Dataslice
# 14                                                NaN  Step_Metrics
# 15                                                NaN       Metrics
# 16                                                NaN  Step_Metrics
# 17                                                NaN         Model
# 18                                                NaN         numpy
# 19                                                NaN         numpy
# 20                                                NaN     Dataslice
# 21                                                NaN  Step_Metrics
# 22                                                NaN       Metrics
# 23                                                NaN  Step_Metrics
# 24                                                NaN         Model
# 25                                                NaN       Dataset
# 26                                                NaN       Dataset
# 27                                                NaN     Dataslice
#
#                                      uri  \
# 0       84e52a5da234c849655b276561889960
# 1       0eef7540aa910839ad064798927b5b78
# 2       60c0ebf589d21493fcd7ee6744558063
# 3       34d783f5cd5f76dcd4edb6d63779c07c
# 4   1094e374-d421-11ed-a37a-d4c9efcecfde
# 5       8f328f08a1cc232c1aaf92a7ec038405
# 6       43b7ae48099741419a1cf520b8ac8fae
# 7       13840834c91f4a2f1925dc7cd6949688
# 8   02c34248-d482-11ed-a37a-d4c9efcecfde
# 9       16de902f650a94db87d7c83f74b87eef
# 10      94f49728e04dbde790b46c7c4d462d88
# 11      c534ea8d9bb64a9b68802334cda12d11
# 12      7013dd0522de32928fb216366458140f
# 13      3eef0041cb7851dc19f5509201246d18
# 14      80346286df44b7e2213cee9516bb6e64
# 15  2f2b64fe-d424-11ed-a37a-d4c9efcecfde
# 16      388f94930ac804605b96ba8127d214ef
# 17      6b4c9484d65e6357b694125fe9bd842e
# 18      60632314f146caeefa4622bd38ebfbd7
# 19      4b3e007d73b2ead9daaa058f365b412a
# 20      6267c2069f4b3e5aea8ee2f8c012c4de
# 21      fd4f4f1a73f77d23be7ae7c7f72c834a
# 22  0001291c-d428-11ed-a37a-d4c9efcecfde
# 23      1f2b2a69ba0641501e62b63e8ef389f5
# 24      ebd5ec89297061df40174a5db5c74ec2
# 25      92a6915b498ac2e6e59777e0043cd004
# 26      f074bd626265edd57175a8a5ecc0f081
# 27      e95c79451b72ff42ee4a168c84cea684
#
#                                                   url   val/mAP
# 0   active_learning:/tmp/myremote/84/e52a5da234c84...       NaN
# 1                                                 NaN       NaN
# 2   active_learning:/tmp/myremote/60/c0ebf589d2149...       NaN
# 3                                                 NaN       NaN
# 4                                                 NaN  0.123142
# 5                                                 NaN       NaN
# 6   active_learning:/tmp/myremote/43/b7ae480997414...       NaN
# 7                                                 NaN       NaN
# 8                                                 NaN  0.123142
# 9                                                 NaN       NaN
# 10  active_learning_demo:/tmp/myremote/94/f49728e0...       NaN
# 11  active_learning:/tmp/myremote/c5/34ea8d9bb64a9...       NaN
# 12  active_learning:/tmp/myremote/70/13dd0522de329...       NaN
# 13                                                NaN       NaN
# 14                                                NaN       NaN
# 15                                                NaN  0.123142
# 16                                                NaN       NaN
# 17  active_learning:/tmp/myremote/6b/4c9484d65e635...       NaN
# 18  active_learning:/tmp/myremote/60/632314f146cae...       NaN
# 19  active_learning:/tmp/myremote/4b/3e007d73b2ead...       NaN
# 20                                                NaN       NaN
# 21                                                NaN       NaN
# 22                                                NaN  0.123142
# 23                                                NaN       NaN
# 24  active_learning:/tmp/myremote/eb/d5ec89297061d...       NaN
# 25  active_learning:/tmp/myremote/92/a6915b498ac2e...       NaN
# 26  active_learning:/tmp/myremote/f0/74bd626265edd...       NaN
# 27                                                NaN       NaN
#
# [28 rows x 23 columns]

# %% [markdown]
# ### Get all the parent artifacts of an artifact. Provides the artifact lineage chain of predecessors

# %%
linked = query.get_all_parent_artifacts(linked.iloc[0]["name"])
display(linked)

# %%
linked = query.get_all_child_artifacts(linked.iloc[0]["name"])
display(linked)

# %% [markdown]
# ### Get immediate child artifacts of an artifact.

# %%
linked = query.get_one_hop_child_artifacts(artifact_name)
display(linked)

# %% [markdown]
# ### Get all child artifacts

# %%
linked = query.get_all_child_artifacts(artifact_name)
display(linked)

# %%
# Provide Execution id corresponding to a Evaluate stage
linked = query.get_all_artifacts_for_execution(4)
for index, row in linked.iterrows():
    if row["type"] == "Step_Metrics":
        break

# %% [markdown]
# ### Get artifact

# %%
artifact = query.get_artifact(row["name"])
display(artifact)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 artifact = query.get_artifact(row["name"])
#       2 display(artifact)
#
# NameError: name 'row' is not defined

# %%
artifacts = query.get_artifact("metrics_1:fd4f4f1a73f77d23be7ae7c7f72c834a:6:f8e54b50-d426-11ed-a37a-d4c9efcecfde")
display(artifacts)
# Out:
#    id          type                               uri  \
# 0  19  Step_Metrics  fd4f4f1a73f77d23be7ae7c7f72c834a
#
#                                                 name  create_time_since_epoch  \
# 0  metrics_1:fd4f4f1a73f77d23be7ae7c7f72c834a:6:f...            1680749936798
#
#    last_update_time_since_epoch       Name                            Commit
# 0                 1680749936798  metrics_1  fd4f4f1a73f77d23be7ae7c7f72c834a

# %%
df = query.read_dataslice("slice_1")
df = df.drop("Uncertinity", axis = 1)
display(df)
# Out:
#                                                       cluster_distance
# Path
# hdcdatasets/hdc_single/JPEGImages/000107.jpg       0.45611964897696833
# hdcdatasets/hdc_single/JPEGImages/000174.jpg        0.9033231539802643
# hdcdatasets/hdc_single/JPEGImages/000211.jpg        0.4343754968307887
# hdcdatasets/hdc_single/JPEGImages/000228.jpg        0.5006266907917188
# hdcdatasets/hdc_single/JPEGImages/000242.jpg        0.8113594841043066
# ...                                                                ...
# hdcdatasets/hdc_single/JPEGImages/2011_003066.jpg   0.4562636710967408
# hdcdatasets/hdc_single/JPEGImages/2011_003194.jpg   0.7199558878656946
# hdcdatasets/hdc_single/JPEGImages/2011_003230.jpg   0.5480589223524482
# hdcdatasets/hdc_single/JPEGImages/2011_003238.jpg   0.7264216245977809
# hdcdatasets/hdc_single/JPEGImages/2011_003242.jpg  0.06922259668603459
#
# [1240 rows x 1 columns]

# %%
df = query.get_artifact("slice_2:6267c2069f4b3e5aea8ee2f8c012c4de")
display(df)
df1 = df.drop(df.columns.difference(['name','median','mean']), axis=1, inplace=False)
df = query.get_artifact("slice_1:3eef0041cb7851dc19f5509201246d18")
df2 = df.drop(df.columns.difference(['name','median','mean']), axis=1, inplace=False)

df = query.get_artifact("slice_3:e95c79451b72ff42ee4a168c84cea684")
df3 = df.drop(df.columns.difference(['name','median','mean']), axis=1, inplace=False)
df = pd.concat([df2, df1, df3], axis=1)
print(df)
# Out:
#    id       type                               uri  \
# 0  18  Dataslice  6267c2069f4b3e5aea8ee2f8c012c4de
#
#                                        name  create_time_since_epoch  \
# 0  slice_2:6267c2069f4b3e5aea8ee2f8c012c4de            1680749417271
#
#    last_update_time_since_epoch  \
# 0                 1680749417271
#
#                                             Remote           mean  \
# 0  /tmp/myremote/62/67c2069f4b3e5aea8ee2f8c012c4de  6.0782277e-06
#
#          median     git_repo                            Commit
# 0  6.097564e-06  /tmp/remote  6267c2069f4b3e5aea8ee2f8c012c4de
#                                        name          mean         median  \
# 0  slice_1:3eef0041cb7851dc19f5509201246d18  7.785772e-08  7.7003534e-08
#
#                                        name           mean        median  \
# 0  slice_2:6267c2069f4b3e5aea8ee2f8c012c4de  6.0782277e-06  6.097564e-06
#
#                                        name         median           mean
# 0  slice_3:e95c79451b72ff42ee4a168c84cea684  1.3451602e-06  1.3491577e-06

# %%
#df = query.get_metrics("metrics_1:388f94930ac804605b96ba8127d214ef:4:30980540-d424-11ed-a37a-d4c9efcecfde")
df = pd.read_parquet("metrics_1")
display(df)
# Out:
#                 train/l_det_cls  train/l_det_loc  train/l_imgcls  train/L_det  \
# SequenceNumber
# 1                      0.089573              0.0        1.313254     1.402827
# 2                      0.086868              0.0        1.313254     1.400122
# 3                           NaN              NaN             NaN          NaN
#
#                 train/grad_norm  learning_rate  momentum  val/mAP
# SequenceNumber
# 1                      0.086545          0.001       0.9      NaN
# 2                      0.103774          0.001       0.9      NaN
# 3                           NaN          0.001       0.9      0.0
